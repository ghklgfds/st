# %% [markdown]
# <a href="https://colab.research.google.com/github/ghklgfds/st/blob/main/rakuma0624.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! /usr/bin/env python3
# coding: utf-8
 
import pandas as pd
import requests
import bs4
import re
import time
import csv
 
response=[]
titles=[]
authors=[]
prices=[]
stocks=[]
urls=[]
images=[]
aprice=[]
 
def postsget(y):
  #print('p')
  headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.84 Safari/537.36'}
     
  search_url = 'https://fril.jp/category/'+str(z)+'/page/'+str(y)
 #print('ロボット：調査中...')
  r = requests.get(search_url, headers=headers)
  #print(r)
  time.sleep(3)
  soup = bs4.BeautifulSoup(r.text, 'lxml') 
  
  #print(soup)
  posts = soup.select(".col-lg-12.col-md-12.col-sm-12.col-xs-12")
  #print(posts)
  return posts
 #print posts,sw 
 
def postanalyse(posts):
    #print('q')
    a=[]
    data=[]
    prices=[]
    names = []
    states = []
    #print(cup[0])
    for p in posts:
     #print(p)
     elems = p.select(".item-list-box__item-price")
     price2=[]
     for g in elems:
            price2=g.getText()
            p=(price2.replace('￥','').replace(' ','').replace(',',''))
            prices.append(p)
    #print(prices)
  
 
 #print(prices)
    for p2 in posts:
            elems2 = p2.select(".ga-class.ga-items-item.link_category_title")
            for g2 in elems2:
      #print(type(g2))
                 names.append(g2.getText())
    #print(names)
  
    for p3 in posts:
        state=[]
        state=p3.select(".item-list-box__soldout_ribbon")
        
        
            
             
  #print(state)
             #if state =="":
               #state= "999"
             
             #if len(state)==1:
                 #a=['+']
                 
             #else:
                 #a=['-']
             #a.append(a)
             
    data=[names,prices,state]
    #print(data)
    df=pd.DataFrame(data)
    #print(df)
    df.T.to_csv('/content/drive/MyDrive/0107rakuma.csv',mode='a')
    #df2=pd.DataFrame(prices)
    #df2.T.to_csv('rakuma.csv',mode='a')
    #df3=pd.DataFrame(state)
    #df3.T.to_csv('rakuma.csv',mode='a')
    
    #print(data)
                 
    #print(a)
 
z=734
y=1
tank2=[]
while True:
    posts=postsget(y)
    postanalyse(posts)
    
    y=y+1
    if y>50:
        
        #print(y)
        
        
    
        y=1
        z=z+1
        print(z)
        if z==746:
            
            
            break
        
    #print(y)
    
#yafuac()
